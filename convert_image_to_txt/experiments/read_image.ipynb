# %%
#Cùng 1 file ảnh nhưng có nhiều cách đọc khác nhau
#Cách 1: Đọc ảnh bằng thư viện PIL
from PIL import Image
import pytesseract
import cv2
import numpy as np

# %%
img_path = 'bridge_game.jpg'
img = Image.open(img_path)
type(img)
#show image in jupyter notebook
img_np = np.array(img)
#show img_np 
img_np
#gray scale
img_gray = img.convert('L')
img_gray_np = np.array(img_gray)
#show img_gray_np
img_gray_np
img_gray_np.shape
# Out:
# (382, 385)

# %%
from matplotlib import pyplot as plt
plt.imshow(img)
plt.show()

# %%
#resize image
img_resize = img.resize((28*9, 28*9))
plt.imshow(img_resize)
plt.show()

# %%
from crop_white_corner import CropWhiteCorner


img_big_raw = Image.open('big_bridge.jpg')
img_big = img_big_raw.convert('L')
img_big_np = np.array(img_big)
#lam gray

#crop
crop_white_corner = CropWhiteCorner(img_big_np)
img_big_crop_white=  crop_white_corner.crop()
plt.imshow(img_big_crop_white)
plt.show()
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
#resize img_big_ră
img_resize = img_big_raw.resize((14*28,22*28))
img_resize2 = img_big_crop_white.resize((14*28, 22*28))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 #resize img_big_ră
#       2 img_resize = img_big_raw.resize((14*28,22*28))
# ----> 3 img_resize2 = img_big_crop_white.resize((14*28, 22*28))
#
# ValueError: resize only works on single-segment arrays
